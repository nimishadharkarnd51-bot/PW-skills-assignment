# %% [markdown]
# <a href="https://colab.research.google.com/github/nimishadharkarnd51-bot/PW-skills-assignment/blob/main/Python_OOPS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. What is Object-Oriented Programming (OOP)
# Answer - OOP is a method of programming where you create objects that contain data (attributes) and behavior (methods).
# our Pillars of OOP
# 1. Encapsulation
#
# Wrapping data and functions together into a single unit (class).
#
# 2. Inheritance
#
# One class can inherit properties and methods from another.
#
# 3. Polymorphism
#
# Same function name can behave differently in different classes.
#
# 4. Abstraction
#
# Hiding complex details and showing only essential features.
#
# ✅ Example (Simple Python OOP Example)
# class Dog:
#     def __init__(self, name, breed):
#         self.name = name       # attribute
#         self.breed = breed     # attribute
#
#     def bark(self):            # method
#         print(f"{self.name} is barking!")
#
# # creating object
# d = Dog("Tommy", "Labrador")
# d.bark()

# %% [markdown]
# #2 What is a class in OOP
# Answer - A class in Object-Oriented Programming (OOP) is a blueprint or template for creating objects.
# A class defines:
#
# Attributes (data/variables)
#
# Methods (functions/behavior)
#
# Objects are created from a class.
#
# 🧱 Think of a class like a blueprint of a house
#
# The class is the blueprint
#
# Objects are the actual houses built using the blueprint
#
# ✅ Python Example of a Class
# class Car:
#     def __init__(self, brand, model):
#         self.brand = brand      # attribute
#         self.model = model      # attribute
#
#     def start(self):            # method
#         print(f"{self.brand} {self.model} is starting.")

# %% [markdown]
# # 3 What is an object in OOP
# Answer - In Object-Oriented Programming (OOP), an object is:
#
# ✅ A real-world entity represented in a program.
#
# It is an instance of a class — meaning it is created from a class and contains data (attributes) and behaviors (methods).
# An object is something built using that blueprint.
#
# Example:
#
# Class: Car blueprint
#
# Object: A specific car like Honda City, BMW X5, etc.
#
# Each object has:
#
# Attributes (data): color, model, speed
#
# Methods (actions): start(), stop(), accelerate()
#
# 🔧 Example in Python
# class Car:
#     def __init__(self, brand, color):
#         self.brand = brand
#         self.color = color
#
#     def drive(self):
#         print(self.brand, "is driving")
#
# # Creating objects
# car1 = Car("BMW", "Black")
# car2 = Car("Honda", "Red")
#
# car1.drive()
# car2.drive()

# %% [markdown]
# # 4 What is the difference between abstraction and encapsulation
# Answer - 1. Abstraction
# Definition:
#
# Abstraction means showing only essential details and hiding the unnecessary details from the user.
#
# Goal:
#
# To reduce complexity by focusing on what an object does, not how it does it.
#
# Example:
#
# When you use a mobile phone, you only see buttons/UI —
# you don’t see the internal circuits, battery logic, etc.
#
# 🔒 2. Encapsulation
# Definition:
#
# Encapsulation means binding data and methods into a single unit (class) and protecting the data using access modifiers.
#
# Goal:
#
# To protect data and prevent direct access or modification.
#
# Example:
#
# In a class, variables are often declared private, and we use getters & setters to control access.

# %% [markdown]
# #5 What are dunder methods in Python
# Answer - Dunder methods in Python (also called magic methods or special methods) are predefined methods with double underscores (__) at the beginning and end of their names.
#
# They allow you to customize how objects behave, such as how they are created, represented, compared, added, or used with built-in functions.
# Because they start and end with double underscores:
#
# 👉 duble nderscore → dunder
#
# Example: __init__, __str__, __len__, etc.

# %% [markdown]
# #6 Explain the concept of inheritance in OOP
# Answer - nheritance in Object-Oriented Programming (OOP) is a concept where one class acquires the properties and behaviors (attributes and methods) of another class.
#
# It allows you to create a new class (child) based on an existing class (parent).
# Inheritance means one class can use the code of another class without rewriting it.
#
# 🧭 Why is Inheritance used?
#
# ✔ Reuse existing code
# ✔ Reduce duplication
# ✔ Make code organized
# ✔ Build hierarchical relationships (Parent → Child)
#
# 🏗 Types of Classes
#
# Parent class / Base class / Super class
# → The class whose features are inherited
#
# Child class / Subclass / Derived class
# → The class that inherits
#
# 📘 Example (Real Life)
#
# Parent class: Vehicle
# Attributes: speed, color
# Methods: start(), stop()
#
# Child class: Car
# Inherits all vehicle features and can add its own like: play_music()

# %% [markdown]
# #7 What is polymorphism in OOP
# Answer - Polymorphism in Object-Oriented Programming (OOP) means one thing can have many forms.
#
# It allows the same function or method name to behave differently depending on the object that calls it.
# Polymorphism = Same name, different behavior
#
# 🧠 Real-Life Example
#
# Think of the word "run":
#
# A person runs
#
# A program runs
#
# A machine runs
#
# Same action name, but different meanings depending on the context.
#
# That’s polymorphism.

# %% [markdown]
# #8 How is encapsulation achieved in Python
# Answer - Encapsulation in Python is achieved by restricting access to class variables and methods using:
#
# ✔ Private members (__variable)
# ✔ Protected members (_variable)
# ✔ Getters and Setters (methods to access/update private data)
# ✔ Using classes to bundle data + methods together.
# 1. Using Private Variables (__name)
#
# Prefixing a variable with double underscore makes it private.
#
# class Person:
#     def __init__(self, name, age):
#         self.__name = name   # private variable
#         self.__age = age     # private variable
#
#
# Private variables cannot be accessed directly from outside the class.
# 2. Using Getters and Setters
#
# To access or modify private variables safely:
#
# class Person:
#     def __init__(self, age):
#         self.__age = age
#
#     def get_age(self):      # getter
#         return self.__age
#
#     def set_age(self, age): # setter
#         if age > 0:
#             self.__age = age
#
#
# Usage:
#
# p = Person(20)
# print(p.get_age())
# p.set_age(25)
#
#
# This ensures data protection.
# 3. Using Protected Variables (_name)
#
# A single underscore means “protected” (convention).
#
# class Student:
#     def __init__(self):
#         self._marks = 80  # protected
#
#
# They can be accessed, but programmers treat them as internal.
# 4. Bundling Data + Methods Together
#
# Encapsulation also means combining related data + methods in one class.
#
# class BankAccount:
#     def __init__(self, balance):
#         self.__balance = balance
#
#     def deposit(self, amt):
#         self.__balance += amt
#
#     def get_balance(self):
#         return self.__balance

# %% [markdown]
# #9 What is a constructor in Python?
# Answer - A constructor in Python is a special method that is automatically called when an object of a class is created.
#
# In Python, the constructor method is:
#
# 🔧 __init__()
# A constructor is a method that initializes the object’s attributes when the object is created.
#
# 🧠 Purpose of a Constructor
#
# ✔ Set initial values for object attributes
# ✔ Allocate resources
# ✔ Run startup code for the object.
# Example
# class Person:
#     def __init__(self, name, age):
#         self.name = name      # attribute initialization
#         self.age = age
#
# # Creating object
# p = Person("Nimisha", 22)
#
# print(p.name)
# print(p.age)
#
#
# When you write:
#
# p = Person("Nimisha", 22)
#
#
# Python automatically calls:
#
# __init__(p, "Nimisha", 22)

# %% [markdown]
# # 10 What are class and static methods in Python
# Answer - In Python, class methods and static methods are special types of methods that belong to a class, not just to objects.
#
# They are defined using decorators:
#
# @classmethod
#
# @staticmethod
# 1. Class Method (@classmethod)
# ✔ A class method receives the class as the first argument (not object).
#
# The first parameter is cls.
#
# It can:
#
# Access class variables
#
# Modify class-level data
#
# Be called using class or object
# 2. Static Method (@staticmethod)
# ✔ A static method does NOT take class (cls) or object (self) as arguments.
#
# It behaves like a normal function but is inside the class for organization.
#
# It can:
#
# Perform utility tasks
#
# Be called with class or object
#
# NOT access class or object data directly

# %% [markdown]
# #11 What is method overloading in Python
# Answer - In Python, method overloading means having multiple methods with the same name but different parameters — but Python does NOT support true method overloading like Java or C++.
#
# However, Python achieves overloading behavior using:
#
# ✔ Default arguments
# ✔ Variable-length arguments (*args, **kwargs)
# Python does not support traditional method overloading.
# But it allows similar behavior using default parameters and *args, enabling a single method to handle multiple argument combinations.

# %% [markdown]
# #12 What is method overriding in OOP
# Answer - Method overriding in OOP is a concept where a child class provides its own version of a method that already exists in its parent class.
#
# The method name is the same, but the implementation is different.
# Method overriding happens when a subclass rewrites a method of the parent class to change its behavior.
# Key Rules of Method Overriding
#
# Same method name
#
# Same parameters
#
# Occurs between parent and child classes
#
# The child method replaces the parent method during runtime

# %% [markdown]
# # 13 What is a property decorator in Python
# Answer - The @property decorator in Python is used to turn a class method into an attribute, allowing you to access methods like variables while still keeping control over data (encapsulation).
#
# It helps implement getter, setter, and deleter methods in a clean, pythonic way.
# A property decorator allows you to access a method like an attribute, without using parentheses.
# The @property decorator converts a method into an attribute and allows controlled access using getter, setter, and deleter methods, helping with encapsulation and clean syntax.
# Example - class Student:
#     def __init__(self, marks):
#         self._marks = marks
#
#     @property
#     def marks(self):
#         return self._marks

# %% [markdown]
# #14 Why is polymorphism important in OOP
# Answer - Polymorphism is very important in OOP because it makes programs flexible, reusable, and easier to maintain.
# It allows one interface (one method name) to work in different ways depending on the object.
#
# Here’s why polymorphism matters:
# 1. It Allows the Same Code to Work for Different Objects
#
# You can write one function or method and use it for many different classes.
#
# Example:
# for animal in [Dog(), Cat(), Cow()]:
#     animal.sound()
#
#
# Each object responds differently using its own sound() method.
#
# ⭐ 2. It Supports Extensibility (Easy to Add New Classes)
#
# You can add new classes later without changing existing code.
#
# Example: Add a new class Lion → existing loops or functions still work.
#
# ⭐ 3. It Makes Code More Flexible
#
# Polymorphism allows dynamic behavior based on the object type.
#
# This is why:
#
# same method name
#
# same interface
#
# different behaviors
# …becomes possible.
#
# ⭐ 4. It Helps Implement Method Overriding
#
# Overriding enables child classes to change parent class behavior.
#
# This is essential for:
#
# custom behavior
#
# specialized classes
#
# real-world modeling
#
# ⭐ 5. Cleaner, More Organized Code
#
# Without polymorphism, you would need many if-else conditions:
#
# if type == "Dog":
#     bark()
# elif type == "Cat":
#     meow()
#
#
# With polymorphism, the method call is automatic.
#
# ⭐ 6. Valuable for Real-World OOP Design
#
# Many design patterns (like Strategy, Factory, Template Method) depend on polymorphism.

# %% [markdown]
# #15 What is an abstract class in Python?
# Answer - An abstract class in Python is a class that cannot be instantiated (you cannot create objects from it) and is used as a blueprint for other classes.
#
# Python provides abstract classes using the abc module` (Abstract Base Class)
# An abstract class is a class that contains one or more abstract methods—methods that are declared but not implemented.
#
# Child classes must provide the implementation.
# Example
# from abc import ABC, abstractmethod
#
# class Animal(ABC):
#
#     @abstractmethod
#     def sound(self):
#         pass   # no implementation
#
# class Dog(Animal):
#     def sound(self):
#         print("Dog barks")
#
# class Cat(Animal):
#     def sound(self):
#         print("Cat meows")
#
# # a = Animal()  # ❌ Error: cannot instantiate abstract class
# d = Dog()
# d.sound()

# %% [markdown]
# # 16 What are the advantages of OOP
# Answer - Here are the main advantages of OOP explained simply:
#
# 🌟 1. Reusability
#
# OOP allows you to reuse existing code through inheritance.
# Instead of writing the same code again, child classes can reuse parent class features.
#
# ✔ Saves time
# ✔ Reduces code duplication
#
# 🌟 2. Modularity
#
# OOP breaks a program into small, independent modules (classes).
#
# ✔ Easy to understand
# ✔ Easy to organize
# ✔ Easy to modify without affecting other parts
#
# 🌟 3. Encapsulation (Data Protection)
#
# OOP keeps data safe and hidden inside classes.
# Only controlled access is allowed through getters/setters or @property.
#
# ✔ Prevents accidental data modification
# ✔ Protects sensitive information
#
# 🌟 4. Abstraction (Hides Complexity)
#
# OOP lets you hide unnecessary details and show only important features.
#
# Example:
# You call .start() on a car object without knowing how the engine works internally.
#
# ✔ Reduces complexity
# ✔ Makes code cleaner and easier to use
#
# 🌟 5. Polymorphism (Flexibility)
#
# The same function/method can work differently for different objects.
#
# Example:
#
# animal.sound()
#
#
# Works for Dog, Cat, Cow, etc.
#
# ✔ Makes code flexible
# ✔ Helps write generic, reusable functions
#
# 🌟 6. Easy Maintenance & Scalability
#
# Because code is modular and well-structured, OOP programs are:
#
# ✔ Easier to update
# ✔ Easier to debug
# ✔ Easier to extend (add new features)
#
# 🌟 7. Better Real-World Modeling
#
# OOP models real-world entities like:
#
# Person
#
# BankAccount
#
# Car
# Each with their own data and behavior.
#
# ✔ Makes programs logical
# ✔ Matches natural thinking
#
# 🌟 8. Supports Large-Scale Applications
#
# OOP is ideal for big systems (banking apps, games, ERPs, websites) because:
#
# ✔ Structure is clean
# ✔ Teams can work on separate classes
# ✔ Code is reusable and organized

# %% [markdown]
# #17 What is the difference between a class variable and an instance variable
# Answer - Difference Between Class Variable and Instance Variable
# 1. Instance Variable
#
# Belongs to each object (instance) of the class.
#
# Each object gets its own separate copy.
#
# Defined inside the constructor (__init__) using self.
#
# Example
# class Student:
#     def __init__(self, name, age):
#         self.name = name        # instance variable
#         self.age = age          # instance variable
#
# s1 = Student("A", 20)
# s2 = Student("B", 22)
#
# print(s1.name)  # A
# print(s2.name)  # B
#
#
# Here, s1 and s2 have different values for name and age.
#
# 2. Class Variable
#
# Belongs to the class itself, not to individual objects.
#
# Shared across all instances of the class.
#
# Defined outside any method, inside the class.
#
# Example
# class Student:
#     school = "ABC School"   # class variable
#
#     def __init__(self, name):
#         self.name = name    # instance variable
#
# s1 = Student("A")
# s2 = Student("B")
#
# print(s1.school)  # ABC School
# print(s2.school)  # ABC School
#
#
# If you change the class variable:
#
# Student.school = "XYZ School"
#
#
# Both s1 and s2 see the updated value.

# %% [markdown]
# #18 What is multiple inheritance in Python
# Answer - Multiple inheritance allows a class to derive properties from two or more parent classes.
# xample of Multiple Inheritance
# class Father:
#     def father_skill(self):
#         return "Driving"
#
# class Mother:
#     def mother_skill(self):
#         return "Cooking"
#
# class Child(Father, Mother):   # Multiple inheritance
#     def child_skill(self):
#         return "Painting"
#
# c = Child()
# print(c.father_skill())   # Inherited from Father
# print(c.mother_skill())   # Inherited from Mother
# print(c.child_skill())    # Child's own method
#
# 🧠 How Python Handles Multiple Inheritance?
#
# Python uses MRO (Method Resolution Order) — a rule to decide which parent class to check first when looking for a method.
#
# We can check it using:
#
# print(Child.mro())
#
# 👍 Advantages
#
# Reuse code from multiple classes.
#
# Combine functionalities from different parents.
#
# ⚠️ Disadvantages
#
# Can become confusing if two parent classes have the same method (method conflicts).
#
# Harder to maintain when inheritance becomes complex.

# %% [markdown]
# #19 Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in Python
# Answer - In Python, __str__() and __repr__() are dunder methods used to define how an object should be represented as a string.
#
# They are often used to make objects more readable and easier to debug.
#
# 🔍 1. __str__() → User-friendly String Representation
#
# Called when you use print() or str().
#
# Should return a readable, human-friendly description of an object.
#
# Aim: Make the output user-friendly.
#
# ✔ Good for end users
# ✔ Focus on readability
# 2. __repr__() → Developer-friendly String Representation
#
# Called when you use repr() or type the object in the interpreter.
#
# Should return a string that can recreate the object, or at least be unambiguous.
#
# Aim: Clear, precise, for debugging.
#
# ✔ Good for developers
# ✔ Focus on accuracy, not prettiness
# ✔ Often looks like valid Python code

# %% [markdown]
# # 20 What is the significance of the ‘super()’ function in Python
# Answer - The super() function in Python is used to call a method from the parent (super) class inside a child class.
#
# It is most commonly used in inheritance, especially when overriding methods.
# Significance of super() in Python
# 1️⃣ Access parent class methods
#
# When a child class overrides a method, super() allows you to call the parent’s version of that method.
#
# 2️⃣ Avoids using the parent class name directly
#
# This makes code cleaner and prevents errors when class names change.
#
# 3️⃣ Supports multiple inheritance (MRO)
#
# super() follows Method Resolution Order (MRO), ensuring the correct parent method is called even when there are multiple base classes.
#
# 4️⃣ Used commonly with constructors
#
# To run the parent class's constructor inside the child's constructor.

# %% [markdown]
# #21 What is the significance of the __del__ method in Python?
# Answer - The __del__() method in Python is a destructor, which is automatically called when an object is about to be destroyed.
# The __del__() method is used to:
#
# ✅ Perform clean-up actions before an object is removed from memory
#
# Examples:
#
# Closing files
#
# Releasing network connections
#
# Releasing resources
#
# Printing a message when object is deleted

# %% [markdown]
# #22 What is the difference between @staticmethod and @classmethod in Python?
# Answer - 1. @staticmethod
#
# A staticmethod is a method that does NOT take the class or object as a parameter.
#
# ✔ No self
# ✔ No cls
# ✔ Behaves like a normal function inside a class
# ✔ Used when the method logic does not depend on class or instance data
#
# Example:
# class MathOps:
#     @staticmethod
#     def add(a, b):
#         return a + b
#
# print(MathOps.add(5, 3))
#
# 🔍 2. @classmethod
#
# A classmethod takes the class as the first argument, conventionally named cls.
#
# ✔ Receives class info
# ✔ Can modify class variables
# ✔ Can create alternative constructors
#
# Example:
# class Person:
#     count = 0
#
#     @classmethod
#     def increment_count(cls):
#         cls.count += 1

# %% [markdown]
# # 23 How does polymorphism work in Python with inheritance
# Answer - Polymorphism with inheritance in Python means that a child class can provide its own version of a method that already exists in the parent class, and Python decides at runtime which version to call based on the object type.
#
# In simple words:
#
# ➡ Same method name, different behaviors in parent and child classes.
# ➡ Python automatically calls the correct method depending on the object.
# When a subclass overrides a method from its parent class, the child class’s version of the method is used when the object belongs to the child class.
#
# This is called runtime polymorphism or method overriding.
# Example: Polymorphism with Method Overriding
# class Animal:
#     def sound(self):
#         return "Some generic sound"
#
# class Dog(Animal):
#     def sound(self):
#         return "Bark"
#
# class Cat(Animal):
#     def sound(self):
#         return "Meow"
#
# # Polymorphism in action
# animals = [Dog(), Cat(), Animal()]
#
# for a in animals:
#     print(a.sound())
#
# Output
# Bark
# Meow
# Some generic sound
#
#
# ✔ Every object calls its own sound() method,

# %% [markdown]
# #24 What is method chaining in Python OOP?
# Answer - Method chaining in Python OOP is a technique where multiple methods are called on the same object in a single line, one after another.
#
# It works because each method returns the object itself (self), allowing the next method to be called.
# Method chaining means calling methods like this:
#
# obj.method1().method2().method3()
#
#
# Each method must return self.
#
# 🔧 Example of Method Chaining
# class Person:
#     def __init__(self, name):
#         self.name = name
#
#     def set_age(self, age):
#         self.age = age
#         return self      # returning the same object
#
#     def set_city(self, city):
#         self.city = city
#         return self      # returning the same object
#
#     def display(self):
#         print(f"Name: {self.name}, Age: {self.age}, City: {self.city}")
#         return self      # optional
#
# p = Person("Nimisha")
# p.set_age(22).set_city("Pune").display()

# %% [markdown]
# # 25 What is the purpose of the __call__ method in Python
# Answer - The __call__() method in Python allows an object to be called like a function.
#
# It makes an instance callable, meaning you can use parentheses () after the object name as if it were a function.
# __call__() is a special method that executes when you call the object itself.
#
# 🔧 Basic Example
# class Greeter:
#     def __call__(self, name):
#         return f"Hello, {name}!"
#
# g = Greeter()
#
# print(g("Nimisha"))     # calling the object like a function
#
# Output:
# Hello, Nimisha!
#
#
# Because Python internally converts:
#
# g("Nimisha")
# to:
#
# g.__call__("Nimisha")
# Purpose of __call__()
# 1️⃣ Make objects behave like functions
#
# Useful for function wrappers, decorators, and callbacks.
#
# 2️⃣ Maintain state between calls
#
# Unlike normal functions, objects can keep data inside

# %%
#1 Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog that overrides the speak() method to print "Bark!".
class Animal:
    def speak(self):
        print("This animal makes a sound.")

class Dog(Animal):
    def speak(self):
        print("Bark!")

# Creating objects
a = Animal()
d = Dog()

a.speak()
d.speak()
# Out:
# This animal makes a sound.
# Bark!

# %%
#2  Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle from it and implement the area() method in both.
from abc import ABC, abstractmethod
import math

# Abstract class
class Shape(ABC):

    @abstractmethod
    def area(self):
        pass


# Circle class
class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * (self.radius ** 2)


# Rectangle class
class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width


# Testing the classes
c = Circle(5)
r = Rectangle(4, 6)

print("Circle Area:", c.area())
print("Rectangle Area:", r.area())
# Out:
# Circle Area: 78.53981633974483
# Rectangle Area: 24

# %%
#3  Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car and further derive a class ElectricCar that adds a battery attribute.
# Base class
class Vehicle:
    def __init__(self, v_type):
        self.type = v_type


# Derived class from Vehicle
class Car(Vehicle):
    def __init__(self, v_type, brand):
        super().__init__(v_type)
        self.brand = brand


# Further derived class from Car
class ElectricCar(Car):
    def __init__(self, v_type, brand, battery):
        super().__init__(v_type, brand)
        self.battery = battery

    def display_info(self):
        print(f"Type: {self.type}")
        print(f"Brand: {self.brand}")
        print(f"Battery Capacity: {self.battery}")


# Creating an ElectricCar object
e = ElectricCar("Four Wheeler", "Tesla", "75 kWh")
e.display_info()
# Out:
# Type: Four Wheeler
# Brand: Tesla
# Battery Capacity: 75 kWh

# %%
#4 Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes Sparrow and Penguin that override the fly() method.
# Base class
class Bird:
    def fly(self):
        print("Some birds can fly.")

# Derived class 1
class Sparrow(Bird):
    def fly(self):
        print("Sparrow flies high in the sky.")

# Derived class 2
class Penguin(Bird):
    def fly(self):
        print("Penguins cannot fly.")

# Polymorphism demonstration
birds = [Sparrow(), Penguin(), Bird()]

for b in birds:
    b.fly()      # Calls the appropriate fly() method based on object type
# Out:
# Sparrow flies high in the sky.
# Penguins cannot fly.
# Some birds can fly.

# %%
#5 Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes balance and methods to deposit, withdraw, and check balance.
class BankAccount:
    def __init__(self, initial_balance=0):
        self.__balance = initial_balance   # private attribute

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"Deposited: {amount}")
        else:
            print("Invalid deposit amount!")

    def withdraw(self, amount):
        if 0 < amount <= self.__balance:
            self.__balance -= amount
            print(f"Withdrawn: {amount}")
        else:
            print("Insufficient balance or invalid amount!")

    def check_balance(self):
        print(f"Current Balance: {self.__balance}")


# Testing the class
account = BankAccount(500)

account.deposit(200)
account.withdraw(100)
account.check_balance()
# Out:
# Deposited: 200
# Withdrawn: 100
# Current Balance: 600

# %%
#6 Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar and Piano that implement their own version of play()
# Base class
class Instrument:
    def play(self):
        print("This instrument makes a sound.")

# Derived class 1
class Guitar(Instrument):
    def play(self):
        print("Guitar is playing: Strum strum!")

# Derived class 2
class Piano(Instrument):
    def play(self):
        print("Piano is playing: Plink plonk!")

# Runtime polymorphism
instruments = [Guitar(), Piano(), Instrument()]

for inst in instruments:
    inst.play()      # Calls the appropriate version based on object type
# Out:
# Guitar is playing: Strum strum!
# Piano is playing: Plink plonk!
# This instrument makes a sound.

# %%
#7 Create a class MathOperations with a class method add_numbers() to add two numbers and a static method subtract_numbers() to subtract two numbers
class MathOperations:

    @classmethod
    def add_numbers(cls, a, b):
        return a + b

    @staticmethod
    def subtract_numbers(a, b):
        return a - b


# Testing the methods
print("Addition:", MathOperations.add_numbers(10, 5))
print("Subtraction:", MathOperations.subtract_numbers(10, 5))
# Out:
# Addition: 15
# Subtraction: 5

# %%
#8  Implement a class Person with a class method to count the total number of persons created.
class Person:
    count = 0   # class variable

    def __init__(self, name):
        self.name = name
        Person.count += 1   # increase count when a new object is created

    @classmethod
    def total_persons(cls):
        return cls.count


# Creating objects
p1 = Person("Nimisha")
p2 = Person("Rahul")
p3 = Person("Aarav")

# Calling the class method
print("Total Persons Created:", Person.total_persons())
# Out:
# Total Persons Created: 3

# %%
#9  Write a class Fraction with attributes numerator and denominator. Override the str method to display the fraction as "numerator/denominator".
class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    def __str__(self):
        return f"{self.numerator}/{self.denominator}"


# Creating objects and printing
f1 = Fraction(3, 4)
f2 = Fraction(7, 2)

print(f1)   # Output: 3/4
print(f2)   # Output: 7/2
# Out:
# 3/4
# 7/2

# %%
#10 Demonstrate operator overloading by creating a class Vector and overriding the add method to add two vectors.
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    # Operator overloading for +
    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

    # To print the vector properly
    def __str__(self):
        return f"({self.x}, {self.y})"


# Creating vector objects
v1 = Vector(3, 4)
v2 = Vector(1, 2)

# Adding vectors using overloaded +
v3 = v1 + v2

print("Vector 1:", v1)
print("Vector 2:", v2)
print("Vector 3 (v1 + v2):", v3)
# Out:
# Vector 1: (3, 4)
# Vector 2: (1, 2)
# Vector 3 (v1 + v2): (4, 6)

# %%
#11 Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is {name} and I am {age} years old
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old")


# Creating an object of Person
p1 = Person("Nimisha", 22)

# Calling the method
p1.greet()
# Out:
# Hello, my name is Nimisha and I am 22 years old

# %%
#12  Implement a class Student with attributes name and grades. Create a method average_grade() to compute the average of the grades.
class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades  # list of numbers

    def average_grade(self):
        if len(self.grades) == 0:
            return 0
        return sum(self.grades) / len(self.grades)


# Example usage
s1 = Student("Nimisha", [85, 90, 78, 92])

print("Name:", s1.name)
print("Average Grade:", s1.average_grade())
# Out:
# Name: Nimisha
# Average Grade: 86.25

# %%
#13  Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the area.
class Rectangle:
    def __init__(self):
        self.length = 0
        self.width = 0

    def set_dimensions(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width


# Example usage
rect = Rectangle()
rect.set_dimensions(10, 5)

print("Rectangle Area:", rect.area())
# Out:
# Rectangle Area: 50

# %%
#14  Create a class Employee with a method calculate_salary() that computes the salary based on hours worked and hourly rate. Create a derived class Manager that adds a bonus to the salary.
class Employee:
    def __init__(self, hours_worked, hourly_rate):
        self.hours_worked = hours_worked
        self.hourly_rate = hourly_rate

    def calculate_salary(self):
        return self.hours_worked * self.hourly_rate


class Manager(Employee):
    def __init__(self, hours_worked, hourly_rate, bonus):
        super().__init__(hours_worked, hourly_rate)
        self.bonus = bonus

    def calculate_salary(self):
        base_salary = super().calculate_salary()
        return base_salary + self.bonus


# Example usage
emp = Employee(40, 200)
mgr = Manager(40, 200, 5000)

print("Employee Salary:", emp.calculate_salary())
print("Manager Salary:", mgr.calculate_salary())
# Out:
# Employee Salary: 8000
# Manager Salary: 13000

# %%
#15 Create a class Product with attributes name, price, and quantity. Implement a method total_price() that calculates the total price of the product
class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    def total_price(self):
        return self.price * self.quantity


# Example usage
p = Product("Laptop", 50000, 2)
print("Total Price:", p.total_price())
# Out:
# Total Price: 100000

# %%
#16 Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that implement the sound() method.
from abc import ABC, abstractmethod

class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass


class Cow(Animal):
    def sound(self):
        return "Moo"


class Sheep(Animal):
    def sound(self):
        return "Baa"


# Example usage
cow = Cow()
sheep = Sheep()

print("Cow sound:", cow.sound())
print("Sheep sound:", sheep.sound())
# Out:
# Cow sound: Moo
# Sheep sound: Baa

# %%
#17 Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that returns a formatted string with the book's details
class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    def get_book_info(self):
        return f"'{self.title}' by {self.author}, published in {self.year_published}"


# Example usage
book = Book("The Alchemist", "Paulo Coelho", 1988)
print(book.get_book_info())
""
# Out:
# 'The Alchemist' by Paulo Coelho, published in 1988
# ''

# %%
#18  Create a class House with attributes address and price. Create a derived class Mansion that adds an attribute number_of_rooms.
class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price


class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms


# Example usage
m = Mansion("123 Luxury St", 50000000, 12)

print("Address:", m.address)
print("Price:", m.price)
print("Number of Rooms:", m.number_of_rooms)
# Out:
# Address: 123 Luxury St
# Price: 50000000
# Number of Rooms: 12
