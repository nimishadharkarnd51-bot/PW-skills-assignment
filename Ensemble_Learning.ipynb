# %% [markdown]
# <a href="https://colab.research.google.com/github/nimishadharkarnd51-bot/PW-skills-assignment/blob/main/Ensemble_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1 Can we use Bagging for regression problems
# Answer : Yes ✅ Bagging can absolutely be used for regression problems.
#
# 🔹 How Bagging Works for Regression
#
# In regression, Bagging (Bootstrap Aggregating):
#
# Trains multiple regression models on different bootstrap samples of the dataset
#
# Combines their predictions by averaging (instead of majority voting as in classification)
#
# Helps reduce variance and improve model stability

# %% [markdown]
# #2 What is the difference between multiple model training and single model training?
# Answer : The difference between single model training and multiple model training lies in how many models are built, how predictions are made, and the trade-off between simplicity and performance.
#
# 🔹 Single Model Training
#
# In single model training, only one model is trained on the entire dataset.
#
# ✅ Characteristics
#
# Uses the full dataset once
#
# One algorithm → one trained model
#
# Predictions come from a single hypothesis
#
# ✅ Advantages
#
# Simple to implement and interpret
#
# Faster training and lower computational cost
#
# Easier debugging and deployment
#
# ❌ Disadvantages
#
# Sensitive to noise and outliers
#
# Can suffer from high variance or high bias
#
# Limited performance improvement
#
# 📌 Examples
#
# Linear Regression
#
# Logistic Regression
#
# Decision Tree
#
# SVM
#
# 🔹 Multiple Model Training
#
# In multiple model training, several models are trained and combined to make final predictions (also called ensemble learning).
#
# ✅ Characteristics
#
# Trains many models on:
#
# Different data samples (Bagging)
#
# Sequential corrections (Boosting)
#
# Different feature subsets (Random Forest)
#
# Predictions are combined using:
#
# Voting (classification)
#
# Averaging (regression)
#
# ✅ Advantages
#
# Higher accuracy and robustness
#
# Reduces variance and/or bias
#
# Less sensitive to overfitting
#
# ❌ Disadvantages
#
# Higher computational cost
#
# More complex to implement and interpret
#
# Harder to deploy and maintain
#
# 📌 Examples
#
# Bagging
#
# Random Forest
#
# AdaBoost
#
# Gradient Boosting
#
# XGBoost

# %% [markdown]
# #3 Explain the concept of feature randomness in Random Forest
# Answer : Feature Randomness in Random Forest
#
# Feature randomness is a core idea behind the Random Forest algorithm that helps make the model more accurate and robust.
#
# 🔹 What Is Feature Randomness?
#
# Feature randomness means that each decision tree in a Random Forest considers only a random subset of features when splitting a node, instead of evaluating all available features.
#
# If there are p total features
#
# At each split, the tree randomly selects m < p features
#
# The best split is chosen only from those m features

# %% [markdown]
# #4 What is OOB (Out-of-Bag) Score?
# Answer : Out-of-Bag (OOB) score is an internal validation metric used in ensemble models like Random Forest and Bagging to estimate model performance without using a separate validation/test set.
#
# 🔹 Why “Out-of-Bag”?
#
# These models use bootstrap sampling:
#
# Each tree is trained on a random sample drawn with replacement
#
# On average, about 63% of data points are used to train a tree
#
# The remaining ~37% are not used for that tree → called Out-of-Bag samples

# %% [markdown]
# #5 How can you measure the importance of features in a Random Forest model
# Answer : In a Random Forest, feature importance tells us how much each feature contributes to the model’s predictions. There are three commonly used ways to measure feature importance.
#
# 1️⃣ Mean Decrease in Impurity (MDI)
#
# (Default Random Forest Feature Importance)
#
# 🔹 Concept
#
# Each time a feature is used to split a node, it reduces impurity
#
# Gini impurity (classification)
#
# MSE (regression)
#
# The total reduction in impurity is averaged over all trees
#
# Features that reduce impurity more are considered more important

# %% [markdown]
# #6 Explain the working principle of a Bagging Classifier
# Answer : (Bagging = Bootstrap Aggregating)
#
# A Bagging Classifier is an ensemble learning method that improves prediction accuracy and stability by training multiple models on different random samples of the same dataset and combining their outputs.
#
# 🔹 Step-by-Step Working
# 1️⃣ Bootstrap Sampling
#
# From the original dataset, create multiple new datasets
#
# Each dataset is generated by sampling with replacement
#
# Some samples may repeat, while others may be left out
#
# 2️⃣ Train Base Classifiers
#
# Train a separate base classifier (e.g., Decision Tree) on each bootstrap sample
#
# All base models are independent and trained in parallel
#
# 3️⃣ Make Predictions
#
# Each base classifier makes its own prediction for a new data point
#
# 4️⃣ Aggregate Predictions (Voting)
#
# For classification, predictions are combined using majority voting
#
# The class with the most votes becomes the final prediction
#
# 🔹 Why Bagging Works
#
# Individual models may overfit the data
#
# Bagging reduces variance by averaging out errors
#
# Works best with high-variance models (like Decision Trees)
#
# 🔹 Key Characteristics
#
# ✔ Uses bootstrap sampling
# ✔ Models trained independently
# ✔ Reduces overfitting
# ✔ Improves generalization

# %% [markdown]
# #7 How do you evaluate a Bagging Classifier’s performance
# Answer : To evaluate a Bagging Classifier’s performance, we use the same evaluation techniques as other classification models, along with a few methods that are especially suited to bagging.
#
# 🔹 1️⃣ Train–Test Split Evaluation
#
# Split the dataset into training and testing sets and evaluate on unseen data.
#
# Common Metrics
#
# Accuracy
#
# Precision
#
# Recall
#
# F1-score
#
# ROC–AUC
# 2️⃣ Confusion Matrix
#
# Shows correct and incorrect classifications in detail.
# 3️⃣ Cross-Validation
#
# Provides a more reliable estimate by evaluating the model on multiple data splits.
# 4️⃣ Out-of-Bag (OOB) Score
#
# (Bagging-Specific Evaluation)
# Uses samples not included in each bootstrap set
#
# Acts as an internal validation metric
#
# No separate test set required
# 5️⃣ ROC Curve & AUC
#
# Useful for binary classification.

# %% [markdown]
# #8 How does a Bagging Regressor work
# Answer : A Bagging Regressor is an ensemble learning method that improves regression performance by training multiple regression models on different bootstrap samples and averaging their predictions.
# 1️⃣ Bootstrap Sampling
#
# From the original dataset, create multiple datasets by sampling with replacement
#
# Each dataset is slightly different and may contain duplicate records
#
# 2️⃣ Train Base Regressors
#
# Train a separate regression model (commonly a Decision Tree Regressor) on each bootstrap sample
#
# All base models are trained independently and in parallel
#
# 3️⃣ Make Predictions
#
# Each regressor predicts a numerical value for a new data point
#
# 4️⃣ Aggregate Predictions (Averaging)
#
# Final prediction is the average of predictions from all regressors:

# %% [markdown]
# #9 What is the main advantage of ensemble techniques
# Answer : Main Advantage of Ensemble Techniques
#
# The main advantage of ensemble techniques is that they improve prediction accuracy and model robustness by combining multiple models instead of relying on a single model.

# %% [markdown]
# #10 What is the main challenge of ensemble methods
# Answer : The main challenge of ensemble methods is their increased complexity, which leads to higher computational cost and reduced interpretability compared to single models
# Why This Is a Challenge
#
# Ensemble methods combine many models, which means:
#
# More training time
#
# More memory usage
#
# Harder to understand and explain predictions

# %% [markdown]
# #11 Explain the key idea behind ensemble techniques
# Answer : The key idea behind ensemble techniques is to combine multiple models (learners) to produce a single, more accurate and robust prediction than any individual model alone.
# Many weak or diverse models, when combined, can outperform a single strong model.
#
# Each model learns different patterns or makes different errors, and the ensemble aggregates them to reduce overall error.

# %% [markdown]
# #12 What is a Random Forest Classifier
# Answer : A Random Forest Classifier is an ensemble machine learning algorithm that builds many decision trees and combines their predictions using majority voting to perform classification.

# %% [markdown]
# #13 What are the main types of ensemble techniques?
# Answer : Ensemble techniques combine multiple models to improve prediction accuracy and robustness. The three main types are:
#
# 1️⃣ Bagging (Bootstrap Aggregating)
# 🔹 Idea
#
# Train multiple models on different bootstrap samples of the same dataset and combine their predictions.
#
# 🔹 Key Characteristics
#
# Sampling with replacement
#
# Models trained independently
#
# Reduces variance
#
# 🔹 Examples
#
# Bagging Classifier
#
# Random Forest (bagging + feature randomness)
# 2️⃣ Boosting
# 🔹 Idea
#
# Train models sequentially, where each new model focuses on correcting errors made by previous ones.
#
# 🔹 Key Characteristics
#
# Models depend on each other
#
# Reduces bias
#
# Uses weighted samples
#
# 🔹 Examples
#
# AdaBoost
#
# Gradient Boosting
#
# XGBoost
#
# LightGBM
# 3️⃣ Stacking (Stacked Generalization)
# 🔹 Idea
#
# Combine predictions from different models using a meta-learner.
#
# 🔹 Key Characteristics
#
# Uses heterogeneous models
#
# Learns optimal combination
#
# High flexibility
#
# 🔹 Examples
#
# Stacking Classifier
#
# Stacking Regressor

# %% [markdown]
# #14 What is ensemble learning in machine learning
# Answer : Ensemble learning is a machine learning approach where multiple models (called base learners) are trained and combined to make a single, more accurate and robust prediction than any individual model.

# %% [markdown]
# #15 When should we avoid using ensemble methods
# Answer : Although ensemble methods are powerful, there are situations where using them is not ideal.
# 1️⃣ When Interpretability Is Critical
#
# Ensembles act like black boxes
#
# Hard to explain decisions clearly
#
# Avoid ensembles when:
#
# Medical diagnosis explanations are required
#
# Legal, financial, or regulatory decisions need transparency
#
# 🔹 2️⃣ When Computational Resources Are Limited
#
# Ensembles require more memory and processing power
#
# Slower training and prediction
#
# Avoid when:
#
# Running on low-resource systems
#
# Real-time or low-latency applications
#
# 🔹 3️⃣ When Dataset Is Small or Simple
#
# Simple models may perform just as well
#
# Ensembles can overfit small datasets
#
# Avoid when:
#
# Linear or near-linear relationships exist
#
# Very few training samples
#
# 🔹 4️⃣ When Model Performance Is Already Satisfactory
#
# Marginal improvement may not justify complexity
#
# Avoid when:
#
# Single model meets accuracy requirements
#
# Cost–benefit tradeoff is unfavorable
#
# 🔹 5️⃣ When Fast Deployment and Maintenance Are Needed
#
# Ensembles are harder to tune, debug, and update

# %% [markdown]
# #16 How does Bagging help in reducing overfitting
# Answer : Bagging (Bootstrap Aggregating) reduces overfitting by lowering model variance through training multiple models on different bootstrap samples and aggregating their predictions.

# %% [markdown]
# #17 Why is Random Forest better than a single Decision Tree
# Answer : A Random Forest outperforms a single Decision Tree because it reduces overfitting, improves accuracy, and produces more stable predictions by combining many decision trees.

# %% [markdown]
# #18 What is the role of bootstrap sampling in Bagging
# Answer : Bootstrap sampling is the foundation of Bagging (Bootstrap Aggregating). Its role is to create diverse training datasets from the original data so that multiple models learn different patterns, which reduces overfitting and improves generalization.

# %% [markdown]
# #19 What are some real-world applications of ensemble techniques?
# Answer : Ensemble techniques are widely used in real-world systems because they improve accuracy, robustness, and reliability, especially in complex and noisy environments.
# 1️⃣ Finance & Banking 💰
#
# Applications:
#
# Credit scoring
#
# Loan default prediction
#
# Fraud detection
#
# Stock price movement prediction
#
# Why ensembles?
#
# Financial data is noisy and nonlinear
#
# Models like Random Forest and XGBoost reduce risk of wrong decisions
#
# 🔹 2️⃣ Healthcare & Medicine 🏥
#
# Applications:
#
# Disease diagnosis (cancer, diabetes, heart disease)
#
# Medical image classification
#
# Patient risk prediction
#
# Why ensembles?
#
# Higher accuracy is critical
#
# Reduces false positives/negatives
# 3️⃣ E-commerce & Recommendation Systems 🛒
#
# Applications:
#
# Product recommendations
#
# Customer churn prediction
#
# Demand forecasting
#
# Why ensembles?
#
# Combine user behavior, purchase history, and preferences
#
# More personalized and stable predictions
#
# 🔹 4️⃣ Cybersecurity 🔐
#
# Applications:
#
# Spam email detection
#
# Intrusion detection systems
#
# Malware classification
#
# Why ensembles?
#
# Attack patterns change frequently
#
# Ensembles adapt better to new threats
# 5️⃣ Autonomous Vehicles 🚗
#
# Applications:
#
# Object detection
#
# Lane detection
#
# Pedestrian recognition
#
# Why ensembles?
#
# Safety-critical decisions
#
# Combining multiple models reduces error risk
# 6️⃣ Weather Forecasting 🌦️
#
# Applications:
#
# Rainfall prediction
#
# Storm and cyclone forecasting
#
# Temperature prediction
#
# Why ensembles?
#
# Weather systems are chaotic
#
# Ensemble forecasts are more reliable than single models
# 7️⃣ Natural Language Processing (NLP) 🗣️
#
# Applications:
#
# Sentiment analysis
#
# Spam filtering
#
# Text classification
#
# Why ensembles?
#
# Different models capture different language patterns

# %% [markdown]
# #20 What is the difference between Bagging and Boosting?
# Answer : Bagging and Boosting are both ensemble learning techniques, but they differ in how models are trained, how errors are handled, and what kind of problem they mainly solve.
# Core Difference
#
# Bagging reduces variance by training models independently on bootstrap samples, while Boosting reduces bias by training models sequentially and focusing on previous errors.

# %%
#21 Train a Bagging Classifier using Decision Trees on a sample dataset and print model accuracy
# Import required libraries
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.metrics import accuracy_score

# Load sample dataset
data = load_breast_cancer()
X = data.data
y = data.target

# Split into training and testing data
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Create base Decision Tree model
base_model = DecisionTreeClassifier(random_state=42)

# Create Bagging Classifier
bagging_clf = BaggingClassifier(
    estimator=base_model,
    n_estimators=100,
    random_state=42
)

# Train the model
bagging_clf.fit(X_train, y_train)

# Predict on test data
y_pred = bagging_clf.predict(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)

# Print accuracy
print("Bagging Classifier Accuracy:", accuracy)
# Out:
# Bagging Classifier Accuracy: 0.9590643274853801

# %%
#22 Train a Bagging Regressor using Decision Trees and evaluate using Mean Squared Error (MSE
# Import required libraries
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.metrics import mean_squared_error

# Load sample regression dataset
data = fetch_california_housing()
X = data.data
y = data.target

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Create base Decision Tree Regressor
base_model = DecisionTreeRegressor(random_state=42)

# Create Bagging Regressor
bagging_reg = BaggingRegressor(
    estimator=base_model,
    n_estimators=100,
    random_state=42
)

# Train the model
bagging_reg.fit(X_train, y_train)

# Make predictions
y_pred = bagging_reg.predict(X_test)

# Evaluate using Mean Squared Error
mse = mean_squared_error(y_test, y_pred)

# Print MSE
print("Bagging Regressor Mean Squared Error (MSE):", mse)
# Out:
# Bagging Regressor Mean Squared Error (MSE): 0.2568358813508342

# %%
#23 Train a Random Forest Classifier on the Breast Cancer dataset and print feature importance scores
# Import required libraries
import pandas as pd
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# Load Breast Cancer dataset
data = load_breast_cancer()
X = data.data
y = data.target
feature_names = data.feature_names

# Split dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Train Random Forest Classifier
rf_model = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)
rf_model.fit(X_train, y_train)

# Get feature importance scores
importances = rf_model.feature_importances_

# Create a DataFrame for better readability
feature_importance_df = pd.DataFrame({
    "Feature": feature_names,
    "Importance": importances
}).sort_values(by="Importance", ascending=False)

# Print feature importance scores
print(feature_importance_df)
# Out:
#                     Feature  Importance
# 7       mean concave points    0.141934
# 27     worst concave points    0.127136
# 23               worst area    0.118217
# 6            mean concavity    0.080557
# 20             worst radius    0.077975
# 22          worst perimeter    0.074292
# 2            mean perimeter    0.060092
# 3                 mean area    0.053810
# 26          worst concavity    0.041080
# 0               mean radius    0.032312
# 13               area error    0.029538
# 21            worst texture    0.018786
# 25        worst compactness    0.017539
# 10             radius error    0.016435
# 28           worst symmetry    0.012929
# 12          perimeter error    0.011770
# 24         worst smoothness    0.011769
# 1              mean texture    0.011064
# 5          mean compactness    0.009216
# 19  fractal dimension error    0.007135
# 29  worst fractal dimension    0.006924
# 4           mean smoothness    0.006223
# ...

# %%
#24 Train a Random Forest Regressor and compare its performance with a single Decision Tree
# Import required libraries
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

# Load regression dataset
data = fetch_california_housing()
X, y = data.data, data.target

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# ---------------------------
# 1. Decision Tree Regressor
# ---------------------------
dt_model = DecisionTreeRegressor(random_state=42)
dt_model.fit(X_train, y_train)

dt_pred = dt_model.predict(X_test)
dt_mse = mean_squared_error(y_test, dt_pred)
dt_r2 = r2_score(y_test, dt_pred)

# ---------------------------
# 2. Random Forest Regressor
# ---------------------------
rf_model = RandomForestRegressor(
    n_estimators=100,
    random_state=42
)
rf_model.fit(X_train, y_train)

rf_pred = rf_model.predict(X_test)
rf_mse = mean_squared_error(y_test, rf_pred)
rf_r2 = r2_score(y_test, rf_pred)

# ---------------------------
# Print Results
# ---------------------------
print("Decision Tree Regressor:")
print("MSE:", dt_mse)
print("R² Score:", dt_r2)

print("\nRandom Forest Regressor:")
print("MSE:", rf_mse)
print("R² Score:", rf_r2)
# Out:
# Decision Tree Regressor:
# MSE: 0.5280096503174904
# R² Score: 0.5977192261218356
#
# Random Forest Regressor:
# MSE: 0.25650512920799395
# R² Score: 0.8045734925119942

# %%
#25 Compute the Out-of-Bag (OOB) Score for a Random Forest Classifier
# Import required libraries
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# Load Breast Cancer dataset
data = load_breast_cancer()
X, y = data.data, data.target

# Train-test split (test set not required for OOB, but kept for completeness)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Train Random Forest with OOB enabled
rf_model = RandomForestClassifier(
    n_estimators=100,
    oob_score=True,
    bootstrap=True,
    random_state=42
)

rf_model.fit(X_train, y_train)

# Print OOB score
print("Out-of-Bag (OOB) Score:", rf_model.oob_score_)
# Out:
# Out-of-Bag (OOB) Score: 0.9547738693467337

# %%
#26 Train a Bagging Classifier using SVM as a base estimator and print accuracy
# Import required libraries
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.ensemble import BaggingClassifier
from sklearn.metrics import accuracy_score

# Load sample dataset
data = load_breast_cancer()
X, y = data.data, data.target

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Create SVM base estimator
# probability=True is required if using predict_proba (not mandatory for accuracy)
svm_base = SVC(kernel='rbf', probability=True, random_state=42)

# Create Bagging Classifier with SVM
bagging_svm = BaggingClassifier(
    estimator=svm_base,
    n_estimators=20,
    random_state=42
)

# Train the model
bagging_svm.fit(X_train, y_train)

# Predict on test data
y_pred = bagging_svm.predict(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)

# Print accuracy
print("Bagging Classifier (SVM base) Accuracy:", accuracy)
# Out:
# Bagging Classifier (SVM base) Accuracy: 0.9473684210526315

# %%
#27 Train a Random Forest Classifier with different numbers of trees and compare accuracy
# Import required libraries
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# Load dataset
data = load_breast_cancer()
X, y = data.data, data.target

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Different numbers of trees
n_estimators_list = [10, 50, 100, 200]

# Train and evaluate models
for n in n_estimators_list:
    rf = RandomForestClassifier(
        n_estimators=n,
        random_state=42
    )
    rf.fit(X_train, y_train)

    y_pred = rf.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)

    print(f"Number of Trees: {n} | Accuracy: {accuracy:.4f}")
# Out:
# Number of Trees: 10 | Accuracy: 0.9649
# Number of Trees: 50 | Accuracy: 0.9708
# Number of Trees: 100 | Accuracy: 0.9708
# Number of Trees: 200 | Accuracy: 0.9708

# %%
#28 Train a Bagging Classifier using Logistic Regression as a base estimator and print AUC score
# Import required libraries
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import BaggingClassifier
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# Load dataset
data = load_breast_cancer()
X, y = data.data, data.target

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Create Logistic Regression base estimator with scaling
log_reg = Pipeline([
    ("scaler", StandardScaler()),
    ("lr", LogisticRegression(max_iter=1000, solver="liblinear"))
])

# Create Bagging Classifier
bagging_lr = BaggingClassifier(
    estimator=log_reg,
    n_estimators=50,
    random_state=42
)

# Train the model
bagging_lr.fit(X_train, y_train)

# Predict probabilities
y_prob = bagging_lr.predict_proba(X_test)[:, 1]

# Calculate AUC score
auc_score = roc_auc_score(y_test, y_prob)

# Print AUC score
print("Bagging Classifier (Logistic Regression base) AUC Score:", auc_score)
# Out:
# Bagging Classifier (Logistic Regression base) AUC Score: 0.998236331569665

# %%
#29 Train a Random Forest Regressor and analyze feature importance scores
# Import required libraries
import pandas as pd
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

# Load regression dataset
data = fetch_california_housing()
X, y = data.data, data.target
feature_names = data.feature_names

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Train Random Forest Regressor
rf_reg = RandomForestRegressor(
    n_estimators=100,
    random_state=42
)
rf_reg.fit(X_train, y_train)

# Get feature importance scores
importances = rf_reg.feature_importances_

# Create DataFrame for readability
feature_importance_df = pd.DataFrame({
    "Feature": feature_names,
    "Importance": importances
}).sort_values(by="Importance", ascending=False)

# Print feature importance scores
print(feature_importance_df)
# Out:
#       Feature  Importance
# 0      MedInc    0.526011
# 5    AveOccup    0.138220
# 7   Longitude    0.086124
# 6    Latitude    0.086086
# 1    HouseAge    0.054654
# 2    AveRooms    0.047188
# 4  Population    0.031722
# 3   AveBedrms    0.029995

# %%
#30 Train an ensemble model using both Bagging and Random Forest and compare accuracy.
# Import required libraries
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier
from sklearn.metrics import accuracy_score

# Load dataset
data = load_breast_cancer()
X, y = data.data, data.target

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# ---------------------------
# 1. Bagging Classifier
# ---------------------------
bagging = BaggingClassifier(
    estimator=DecisionTreeClassifier(),
    n_estimators=100,
    random_state=42
)

bagging.fit(X_train, y_train)
y_pred_bagging = bagging.predict(X_test)
bagging_accuracy = accuracy_score(y_test, y_pred_bagging)

# ---------------------------
# 2. Random Forest Classifier
# ---------------------------
random_forest = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)

random_forest.fit(X_train, y_train)
y_pred_rf = random_forest.predict(X_test)
rf_accuracy = accuracy_score(y_test, y_pred_rf)

# ---------------------------
# Print Results
# ---------------------------
print("Bagging Classifier Accuracy:", bagging_accuracy)
print("Random Forest Accuracy:", rf_accuracy)
# Out:
# Bagging Classifier Accuracy: 0.9590643274853801
# Random Forest Accuracy: 0.9707602339181286

# %%
#31 Train a Random Forest Classifier and tune hyperparameters using GridSearchCV
# Import required libraries
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# Load dataset
data = load_breast_cancer()
X, y = data.data, data.target

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Create Random Forest model
rf = RandomForestClassifier(random_state=42)

# Define hyperparameter grid
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10],
    'max_features': ['sqrt', 'log2']
}

# Setup GridSearchCV
grid_search = GridSearchCV(
    estimator=rf,
    param_grid=param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1
)

# Perform grid search
grid_search.fit(X_train, y_train)

# Best model from GridSearch
best_rf = grid_search.best_estimator_

# Predict using best model
y_pred = best_rf.predict(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)

# Print results
print("Best Parameters:", grid_search.best_params_)
print("Best Cross-Validation Accuracy:", grid_search.best_score_)
print("Test Accuracy with Tuned Model:", accuracy)
# Out:
# Best Parameters: {'max_depth': None, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 100}
# Best Cross-Validation Accuracy: 0.9522468354430378
# Test Accuracy with Tuned Model: 0.9649122807017544

# %%
#32 Train a Bagging Regressor with different numbers of base estimators and compare performance
# Import required libraries
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.metrics import mean_squared_error

# Load regression dataset
data = fetch_california_housing()
X, y = data.data, data.target

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Different numbers of base estimators
n_estimators_list = [10, 50, 100, 200]

# Train and evaluate models
for n in n_estimators_list:
    bagging_reg = BaggingRegressor(
        estimator=DecisionTreeRegressor(random_state=42),
        n_estimators=n,
        random_state=42
    )

    bagging_reg.fit(X_train, y_train)
    y_pred = bagging_reg.predict(X_test)

    mse = mean_squared_error(y_test, y_pred)
    print(f"Number of Estimators: {n} | MSE: {mse:.4f}")
# Out:
# Number of Estimators: 10 | MSE: 0.2862
# Number of Estimators: 50 | MSE: 0.2579
# Number of Estimators: 100 | MSE: 0.2568
# Number of Estimators: 200 | MSE: 0.2542

# %%
#33 Train a Random Forest Classifier and analyze misclassified samples
# Import required libraries
import pandas as pd
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Load dataset
data = load_breast_cancer()
X, y = data.data, data.target
feature_names = data.feature_names
target_names = data.target_names

# Convert to DataFrame for easier analysis
X_df = pd.DataFrame(X, columns=feature_names)
y_series = pd.Series(y, name="Actual")

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X_df, y_series, test_size=0.3, random_state=42
)

# Train Random Forest Classifier
rf = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)
rf.fit(X_train, y_train)

# Predictions
y_pred = rf.predict(X_test)

# Accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Model Accuracy:", accuracy)

# Confus
# Out:
# Model Accuracy: 0.9707602339181286

# %%
#34 Train a Bagging Classifier and compare its performance with a single Decision Tree Classifier
# Import required libraries
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.metrics import accuracy_score

# Load dataset
data = load_breast_cancer()
X, y = data.data, data.target

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# -----------------------------
# 1. Single Decision Tree
# -----------------------------
dt = DecisionTreeClassifier(random_state=42)
dt.fit(X_train, y_train)

y_pred_dt = dt.predict(X_test)
dt_accuracy = accuracy_score(y_test, y_pred_dt)

# -----------------------------
# 2. Bagging Classifier
# -----------------------------
bagging = BaggingClassifier(
    estimator=DecisionTreeClassifier(random_state=42),
    n_estimators=100,
    random_state=42
)
bagging.fit(X_train, y_train)

y_pred_bag = bagging.predict(X_test)
bagging_accuracy = accuracy_score(y_test, y_pred_bag)

# -----------------------------
# Print Results
# -----------------------------
print("Decision Tree Accuracy:", dt_accuracy)
print("Bagging Classifier Accuracy:", bagging_accuracy)
# Out:
# Decision Tree Accuracy: 0.9415204678362573
# Bagging Classifier Accuracy: 0.9590643274853801

# %%
#35 Train a Random Forest Classifier and visualize the confusion matrix
# Import required libraries
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, accuracy_score

# Load dataset
data = load_breast_cancer()
X, y = data.data, data.target
class_names = data.target_names

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Train Random Forest Classifier
rf = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)
rf.fit(X_train, y_train)

# Predictions
y_pred = rf.predict(X_test)

# Accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Model Accuracy:", accuracy)

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)

# Plot Confusion Matrix
plt.figure(figsize=(6, 4))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=class_names,
    yticklabels=class_names
)
plt.xlabel("Predicted Label")
plt.ylabel("Actual Label")
plt.title("Confusion Matrix - Random Forest Classifier")
plt.show()
# Out:
# Model Accuracy: 0.9707602339181286

# %%
#36 Train a Stacking Classifier using Decision Trees, SVM, and Logistic Regression, and compare accuracy
# Import required libraries
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import StackingClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# Load dataset
data = load_breast_cancer()
X, y = data.data, data.target

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# ----------------------------
# Base Models
# ----------------------------
dt = DecisionTreeClassifier(random_state=42)

svm = Pipeline([
    ("scaler", StandardScaler()),
    ("svm", SVC(probability=True, random_state=42))
])

lr = Pipeline([
    ("scaler", StandardScaler()),
    ("lr", LogisticRegression(max_iter=1000))
])

# ----------------------------
# Train Individual Models
# ----------------------------
dt.fit(X_train, y_train)
svm.fit(X_train, y_train)
lr.fit(X_train, y_train)

dt_acc = accuracy_score(y_test, dt.predict(X_test))
svm_acc = accuracy_score(y_test, svm.predict(X_test))
lr_acc = accuracy_score(y_test, lr.predict(X_test))

# ----------------------------
# Stacking Classifier
# ----------------------------
stacking_clf = StackingClassifier(
    estimators=[
        ("dt", dt),
        ("svm", svm),
        ("lr", lr)
    ],
    final_estimator=LogisticRegression(max_iter=1000),
    cv=5
)

stacking_clf.fit(X_train, y_train)
stacking_pred = stacking_clf.predict(X_test)
stacking_acc = accuracy_score(y_test, stacking_pred)

# ----------------------------
# Print Results
# ----------------------------
print("Decision Tree Accuracy:", dt_acc)
print("SVM Accuracy:", svm_acc)
print("Logistic Regression Accuracy:", lr_acc)
print("Stacking Classifier Accuracy:", stacking_acc)
# Out:
# Decision Tree Accuracy: 0.9415204678362573
# SVM Accuracy: 0.9766081871345029
# Logistic Regression Accuracy: 0.9824561403508771
# Stacking Classifier Accuracy: 0.9883040935672515

# %%
#37 Train a Random Forest Classifier and print the top 5 most important features
# Import required libraries
import pandas as pd
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# Load dataset
data = load_breast_cancer()
X, y = data.data, data.target
feature_names = data.feature_names

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Train Random Forest Classifier
rf = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)
rf.fit(X_train, y_train)

# Get feature importance scores
importances = rf.feature_importances_

# Create DataFrame
feature_importance_df = pd.DataFrame({
    "Feature": feature_names,
    "Importance": importances
})

# Sort and select top 5 features
top_5_features = feature_importance_df.sort_values(
    by="Importance", ascending=False
).head(5)

# Print top 5 most important features
print("Top 5 Most Important Features:")
print(top_5_features)
# Out:
# Top 5 Most Important Features:
#                  Feature  Importance
# 7    mean concave points    0.141934
# 27  worst concave points    0.127136
# 23            worst area    0.118217
# 6         mean concavity    0.080557
# 20          worst radius    0.077975

# %%
#38 Train a Bagging Classifier and evaluate performance using Precision, Recall, and F1-score
# Import required libraries
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.metrics import classification_report

# Load dataset
data = load_breast_cancer()
X, y = data.data, data.target
class_names = data.target_names

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Train Bagging Classifier
bagging = BaggingClassifier(
    estimator=DecisionTreeClassifier(random_state=42),
    n_estimators=100,
    random_state=42
)
bagging.fit(X_train, y_train)

# Predictions
y_pred = bagging.predict(X_test)

# Precision, Recall, F1-score
report = classification_report(
    y_test, y_pred, target_names=class_names
)

print("Classification Report:\n")
print(report)
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#    malignant       0.95      0.94      0.94        63
#       benign       0.96      0.97      0.97       108
#
#     accuracy                           0.96       171
#    macro avg       0.96      0.95      0.96       171
# weighted avg       0.96      0.96      0.96       171

# %%
#39 Train a Random Forest Classifier and analyze the effect of max_depth on accuracy
# Import required libraries
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# Load dataset
data = load_breast_cancer()
X, y = data.data, data.target

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Different max_depth values
max_depth_values = [None, 5, 10, 20, 30]

print("Effect of max_depth on Accuracy:\n")

# Train and evaluate models
for depth in max_depth_values:
    rf = RandomForestClassifier(
        n_estimators=100,
        max_depth=depth,
        random_state=42
    )
    rf.fit(X_train, y_train)

    y_pred = rf.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)

    print(f"max_depth = {depth} | Accuracy = {accuracy:.4f}")
# Out:
# Effect of max_depth on Accuracy:
#
# max_depth = None | Accuracy = 0.9708
# max_depth = 5 | Accuracy = 0.9649
# max_depth = 10 | Accuracy = 0.9708
# max_depth = 20 | Accuracy = 0.9708
# max_depth = 30 | Accuracy = 0.9708

# %%
#40 Train a Bagging Regressor using different base estimators (DecisionTree and KNeighbors) and compare performance
# Import required libraries
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.metrics import mean_squared_error

# Load regression dataset
data = fetch_california_housing()
X, y = data.data, data.target

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# -----------------------------------
# 1. Bagging Regressor with Decision Tree
# -----------------------------------
bagging_dt = BaggingRegressor(
    estimator=DecisionTreeRegressor(random_state=42),
    n_estimators=100,
    random_state=42
)

bagging_dt.fit(X_train, y_train)
y_pred_dt = bagging_dt.predict(X_test)
mse_dt = mean_squared_error(y_test, y_pred_dt)

# -----------------------------------
# 2. Bagging Regressor with KNN
# -----------------------------------
bagging_knn = BaggingRegressor(
    estimator=KNeighborsRegressor(n_neighbors=5),
    n_estimators=100,
    random_state=42
)

bagging_knn.fit(X_train, y_train)
y_pred_knn = bagging_knn.predict(X_test)
mse_knn = mean_squared_error(y_test, y_pred_knn)

# -----------------------------------
# Print Results
# -----------------------------------
print("Bagging Regressor (Decision Tree) MSE:", mse_dt)
print("Bagging Regressor (KNN) MSE:", mse_knn)
# Out:
# Bagging Regressor (Decision Tree) MSE: 0.2568358813508342
# Bagging Regressor (KNN) MSE: 1.0998197296736556

# %%
#41 Train a Random Forest Classifier and evaluate its performance using ROC-AUC Score
# Import required libraries
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score

# Load dataset
data = load_breast_cancer()
X, y = data.data, data.target

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Train Random Forest Classifier
rf = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)
rf.fit(X_train, y_train)

# Predict probabilities for the positive class
y_prob = rf.predict_proba(X_test)[:, 1]

# Calculate ROC-AUC score
roc_auc = roc_auc_score(y_test, y_prob)

# Print ROC-AUC score
print("Random Forest ROC-AUC Score:", roc_auc)
# Out:
# Random Forest ROC-AUC Score: 0.9968400940623163

# %%
#42 Train a Bagging Classifier and evaluate its performance using cross-validatio
# Import required libraries
from sklearn.datasets import load_breast_cancer
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.model_selection import cross_val_score

# Load dataset
data = load_breast_cancer()
X, y = data.data, data.target

# Create Bagging Classifier
bagging_clf = BaggingClassifier(
    estimator=DecisionTreeClassifier(random_state=42),
    n_estimators=100,
    random_state=42
)

# Perform 5-fold cross-validation
cv_scores = cross_val_score(
    bagging_clf,
    X,
    y,
    cv=5,
    scoring='accuracy'
)

# Print cross-validation results
print("Cross-validation accuracy scores:", cv_scores)
print("Mean CV Accuracy:", cv_scores.mean())
print("Standard Deviation:", cv_scores.std())
# Out:
# Cross-validation accuracy scores: [0.89473684 0.93859649 0.99122807 0.96491228 1.        ]
# Mean CV Accuracy: 0.9578947368421054
# Standard Deviation: 0.03819568606504778

# %%
#43 Train a Random Forest Classifier and plot the Precision-Recall curv
# Import required libraries
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_recall_curve, average_precision_score

# Load dataset
data = load_breast_cancer()
X, y = data.data, data.target

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Train Random Forest Classifier
rf = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)
rf.fit(X_train, y_train)

# Predict probabilities for the positive class
y_scores = rf.predict_proba(X_test)[:, 1]

# Compute Precision-Recall values
precision, recall, thresholds = precision_recall_curve(y_test, y_scores)

# Compute Average Precision (AP) score
avg_precision = average_precision_score(y_test, y_scores)

# Plot Precision-Recall Curve
plt.figure()
plt.plot(recall, precision, label=f"Random Forest (AP = {avg_precision:.2f})")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision–Recall Curve - Random Forest Classifier")
plt.legend()
plt.grid(True)
plt.show()

# %%
#44 Train a Stacking Classifier with Random Forest and Logistic Regression and compare accuracy
# Import required libraries
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_recall_curve, average_precision_score

# Load dataset
data = load_breast_cancer()
X, y = data.data, data.target

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Train Random Forest Classifier
rf = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)
rf.fit(X_train, y_train)

# Predict probabilities for the positive class
y_scores = rf.predict_proba(X_test)[:, 1]

# Compute Precision-Recall values
precision, recall, thresholds = precision_recall_curve(y_test, y_scores)

# Compute Average Precision (AP) score
avg_precision = average_precision_score(y_test, y_scores)

# Plot Precision-Recall Curve
plt.figure()
plt.plot(recall, precision, label=f"Random Forest (AP = {avg_precision:.2f})")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision–Recall Curve - Random Forest Classifier")
plt.legend()
plt.grid(True)
plt.show()

# %%
#45 Train a Bagging Regressor with different levels of bootstrap samples and compare performance.
# Import required libraries
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.metrics import mean_squared_error

# Load regression dataset
data = fetch_california_housing()
X, y = data.data, data.target

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Different bootstrap sample sizes
max_samples_list = [0.5, 0.7, 1.0]

print("Effect of Bootstrap Sample Size on Performance:\n")

# Train and evaluate models
for sample_size in max_samples_list:
    bagging_reg = BaggingRegressor(
        estimator=DecisionTreeRegressor(random_state=42),
        n_estimators=100,
        max_samples=sample_size,
        bootstrap=True,
        random_state=42
    )

    bagging_reg.fit(X_train, y_train)
    y_pred = bagging_reg.predict(X_test)

    mse = mean_squared_error(y_test, y_pred)
    print(f"max_samples = {sample_size} | MSE = {mse:.4f}")
# Out:
# Effect of Bootstrap Sample Size on Performance:
#
# max_samples = 0.5 | MSE = 0.2626
# max_samples = 0.7 | MSE = 0.2585
# max_samples = 1.0 | MSE = 0.2568
